# %% [markdown]
# 1.   Apa kategori barang yang paling banyak dibeli dan paling sedikit diminati?
# 2.   Bulan apa yang terjadi penjualan tertinggi?
# 3.   Hari apa yang sering digunakan oleh pembeli untuk melakukan transaksi?

# %%
# import packages packages yang akan digunakan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %%
customers = pd.read_csv("customers_dataset.csv")
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation = pd.read_csv("geolocation_dataset.csv")
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items = pd.read_csv("order_items_dataset.csv")
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_payments = pd.read_csv("order_payments_dataset.csv")
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
orders = pd.read_csv("orders_dataset.csv")
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
product_name = pd.read_csv("product_category_name_translation.csv")
product_name.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products = pd.read_csv("products_dataset.csv")
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
customers = pd.read_csv("customers_dataset.csv")
geolocation = pd.read_csv("geolocation_dataset.csv")
order_items = pd.read_csv("order_items_dataset.csv")
order_payments = pd.read_csv("order_payments_dataset.csv")
orders = pd.read_csv("orders_dataset.csv")
product_name = pd.read_csv("product_category_name_translation.csv")
products = pd.read_csv("products_dataset.csv")
sellers = pd.read_csv("sellers_dataset.csv")

# %%
sellers = pd.read_csv("sellers_dataset.csv")
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# # Menggabungnkan Data Frame

# %%
product_name_df = pd.merge(
    left=products,
    right=product_name,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_name_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
df_product_name = product_name_df[["product_id","product_category_name","product_category_name_english"]]
df_product_name.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
order_product = pd.merge(
    left= order_items,
    right=df_product_name,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_product.head()

# %%
seller_product = pd.merge(
    left= order_product,
    right=sellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
seller_product.head()

# %%
geolocation = geolocation.drop_duplicates(subset=['geolocation_zip_code_prefix'])
geolocation.head()

# %%
df_order = seller_product.merge(geolocation, left_on='seller_zip_code_prefix',
                                right_on='geolocation_zip_code_prefix', how='left')
df_order.head()

# %%
df_order = df_order.drop(columns = ['geolocation_city','geolocation_state'])

# %%
df_order.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# 2  2018-01-18 14:48:30  199.00          17.87      moveis_decoracao
# 3  2018-08-15 10:10:18   12.99          12.79            perfumaria
# 4  2017-02-13 13:57:51  199.90          18.14    ferramentas_jardim
#
#   product_category_name_english  seller_zip_code_prefix    seller_city  \
# 0                    cool_stuff                   27277  volta redonda
# 1                      pet_shop                    3471      sao paulo
# 2               furniture_decor                   37564  borda da mata
# 3                     perfumery                   14403         franca
# 4                  garden_tools                   87900         loanda
#
#   seller_state  geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0           SP                      27277.0       -22.498183       -44.123614
# 1           SP                       3471.0       -23.566258       -46.518417
# 2           MG                      37564.0       -22.264094       -46.158564
# 3           SP                      14403.0       -20.548228       -47.395897
# 4           PR                      87900.0       -22.931427       -53.133759

# %%
orders_payments = pd.merge(
    left= orders,
    right= order_payments,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_payments.head()

# %%
orders_payments = orders_payments.drop(columns = ['payment_sequential','payment_installments'])

# %%
orders_payments.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date payment_type  payment_value
# 0           2017-10-18 00:00:00  credit_card          18.12
# 1           2017-10-18 00:00:00      voucher           2.00
# 2           2017-10-18 00:00:00      voucher          18.59
# 3           2018-08-13 00:00:00       boleto         141.46
# 4           2018-09-04 00:00:00  credit_card         179.12

# %%
customers = customers.drop(columns = ['customer_unique_id'])

# %%
order_customers = orders_payments.merge(customers, left_on='customer_id', right_on='customer_id',how='left')
order_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date payment_type  payment_value  \
# 0           2017-10-18 00:00:00  credit_card          18.12
# 1           2017-10-18 00:00:00      voucher           2.00
# 2           2017-10-18 00:00:00      voucher          18.59
# 3           2018-08-13 00:00:00       boleto         141.46
# 4           2018-09-04 00:00:00  credit_card         179.12
#
#    customer_zip_code_prefix customer_city customer_state
# 0                      3149     sao paulo             SP
# 1                      3149     sao paulo             SP
# 2                      3149     sao paulo             SP
# 3                     47813     barreiras             BA
# 4                     75265    vianopolis             GO

# %%
order =  order_customers.merge(geolocation, left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='left')
order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date payment_type  payment_value  \
# 0           2017-10-18 00:00:00  credit_card          18.12
# 1           2017-10-18 00:00:00      voucher           2.00
# 2           2017-10-18 00:00:00      voucher          18.59
# 3           2018-08-13 00:00:00       boleto         141.46
# 4           2018-09-04 00:00:00  credit_card         179.12
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      3149     sao paulo             SP
# 1                      3149     sao paulo             SP
# 2                      3149     sao paulo             SP
# 3                     47813     barreiras             BA
# 4                     75265    vianopolis             GO
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       3149.0       -23.574809       -46.587471
# 1                       3149.0       -23.574809       -46.587471
# 2                       3149.0       -23.574809       -46.587471
# 3                      47813.0       -12.169860       -44.988369
# 4                      75265.0       -16.746337       -48.514624
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        barreiras                BA
# 4       vianopolis                GO

# %%
order =  order.drop(columns = ['geolocation_city','geolocation_state'])

# %%
order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date payment_type  payment_value  \
# 0           2017-10-18 00:00:00  credit_card          18.12
# 1           2017-10-18 00:00:00      voucher           2.00
# 2           2017-10-18 00:00:00      voucher          18.59
# 3           2018-08-13 00:00:00       boleto         141.46
# 4           2018-09-04 00:00:00  credit_card         179.12
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                      3149     sao paulo             SP
# 1                      3149     sao paulo             SP
# 2                      3149     sao paulo             SP
# 3                     47813     barreiras             BA
# 4                     75265    vianopolis             GO
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                       3149.0       -23.574809       -46.587471
# 1                       3149.0       -23.574809       -46.587471
# 2                       3149.0       -23.574809       -46.587471
# 3                      47813.0       -12.169860       -44.988369
# 4                      75265.0       -16.746337       -48.514624

# %% [markdown]
# 2 data frame yaitu df_order dan order

# %%
df_order.info() # shipping jadiin time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  object
#  3   seller_id                      112650 non-null  object
#  4   shipping_limit_date            112650 non-null  object
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   product_category_name          111047 non-null  object
#  8   product_category_name_english  111023 non-null  object
#  9   seller_zip_code_prefix         112650 non-null  int64
#  10  seller_city                    112650 non-null  object
#  11  seller_state                   112650 non-null  object
#  12  geolocation_zip_code_prefix    112397 non-null  float64
#  13  geolocation_lat                112397 non-null  float64
#  14  geolocation_lng                112397 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 13.8+ MB

# %%
df_order.isna().sum() # Terdapat missing value
# Out:
# order_id                            0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name            1603
# product_category_name_english    1627
# seller_zip_code_prefix              0
# seller_city                         0
# seller_state                        0
# geolocation_zip_code_prefix       253
# geolocation_lat                   253
# geolocation_lng                   253
# dtype: int64

# %%
print("Jumlah duplikasi: ",df_order.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
df_order.describe() # terdapat outlier
# Out:
#        order_item_id          price  freight_value  seller_zip_code_prefix  \
# count  112650.000000  112650.000000  112650.000000           112650.000000
# mean        1.197834     120.653739      19.990320            24439.170431
# std         0.705124     183.633928      15.806405            27596.030909
# min         1.000000       0.850000       0.000000             1001.000000
# 25%         1.000000      39.900000      13.080000             6429.000000
# 50%         1.000000      74.990000      16.260000            13568.000000
# 75%         1.000000     134.900000      21.150000            27930.000000
# max        21.000000    6735.000000     409.680000            99730.000000
#
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                112397.000000    112397.000000    112397.000000
# mean                  24435.840191       -22.800558       -47.235919
# std                   27593.085486         2.697063         2.341211
# min                    1001.000000       -36.605374       -67.809656
# 25%                    6429.000000       -23.610305       -48.831547
# 50%                   13568.000000       -23.422313       -46.747050
# 75%                   27345.000000       -21.766477       -46.518082
# max                   99730.000000        -2.546079       -34.847856

# %%
order.info() # salah tipe data pada order_purchase_timestamp , order_approved_at, order_delivered_carrier_date, order_delivered_customer_date ,order_estimated_delivery_date, order status
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103887 entries, 0 to 103886
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103887 non-null  object
#  1   customer_id                    103887 non-null  object
#  2   order_status                   103887 non-null  object
#  3   order_purchase_timestamp       103887 non-null  object
#  4   order_approved_at              103712 non-null  object
#  5   order_delivered_carrier_date   101999 non-null  object
#  6   order_delivered_customer_date  100755 non-null  object
#  7   order_estimated_delivery_date  103887 non-null  object
#  8   payment_type                   103886 non-null  object
#  9   payment_value                  103886 non-null  float64
#  10  customer_zip_code_prefix       103887 non-null  int64
#  11  customer_city                  103887 non-null  object
#  12  customer_state                 103887 non-null  object
#  13  geolocation_zip_code_prefix    103600 non-null  float64
#  14  geolocation_lat                103600 non-null  float64
#  15  geolocation_lng                103600 non-null  float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 13.5+ MB

# %%
order.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# payment_type                        1
# payment_value                       1
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# geolocation_zip_code_prefix       287
# geolocation_lat                   287
# geolocation_lng                   287
# dtype: int64

# %%
print("Jumlah duplikasi: ",order.duplicated().sum())
# Out:
# Jumlah duplikasi:  615

# %%
order.describe() # Terdapat outlier
# Out:
#        payment_value  customer_zip_code_prefix  geolocation_zip_code_prefix  \
# count  103886.000000             103887.000000                103600.000000
# mean      154.100380              35072.353490                 34993.025290
# std       217.494064              29743.416343                 29728.828785
# min         0.000000               1003.000000                  1003.000000
# 25%        56.790000              11367.500000                 11325.000000
# 50%       100.000000              24360.000000                 24342.000000
# 75%       171.837500              58418.000000                 58102.250000
# max     13664.080000              99990.000000                 99990.000000
#
#        geolocation_lat  geolocation_lng
# count    103600.000000    103600.000000
# mean        -21.182725       -46.161546
# std           5.619097         4.072123
# min         -36.605374       -72.666706
# 25%         -23.587054       -48.080610
# 50%         -22.925319       -46.628693
# 75%         -20.146615       -43.580531
# max          42.184003        -8.577855

# %% [markdown]
# ## Data Cleaning

# %%
df_order["shipping_limit_date"] = pd.to_datetime(df_order["shipping_limit_date"])

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  object
#  3   seller_id                      112650 non-null  object
#  4   shipping_limit_date            112650 non-null  datetime64[ns]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   product_category_name          111047 non-null  object
#  8   product_category_name_english  111023 non-null  object
#  9   seller_zip_code_prefix         112650 non-null  int64
#  10  seller_city                    112650 non-null  object
#  11  seller_state                   112650 non-null  object
#  12  geolocation_zip_code_prefix    112397 non-null  float64
#  13  geolocation_lat                112397 non-null  float64
#  14  geolocation_lng                112397 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(7)
# memory usage: 13.8+ MB

# %%
a = df_order.loc[df_order["product_category_name"].notnull() & df_order["product_category_name_english"].isnull()]
set(a["product_category_name"])
# Out:
# {'pc_gamer', 'portateis_cozinha_e_preparadores_de_alimentos'}

# %%
df_order['product_category_name'].fillna('not defined', inplace=True)
df_order['product_category_name_english'].fillna('not defined', inplace=True)

df_order["product_category_name_english"] =
np.where(df_order["product_category_name"] == 'pc_gamer', 'PC Gaming', df_order["product_category_name_english"])
df_order["product_category_name_english"] =
np.where(df_order["product_category_name"] == 'portateis_cozinha_e_preparadores_de_alimentos', 'portable kitchen food preparers', df_order["product_category_name_english"])

# %%
 df_order.isnull().sum()
# Out:
# order_id                           0
# order_item_id                      0
# product_id                         0
# seller_id                          0
# shipping_limit_date                0
# price                              0
# freight_value                      0
# product_category_name              0
# product_category_name_english      0
# seller_zip_code_prefix             0
# seller_city                        0
# seller_state                       0
# geolocation_zip_code_prefix      253
# geolocation_lat                  253
# geolocation_lng                  253
# dtype: int64

# %%
order['order_purchase_timestamp'] = pd.to_datetime(order['order_purchase_timestamp'])
order['order_approved_at'] = pd.to_datetime(order['order_approved_at'])
order['order_delivered_carrier_date'] = pd.to_datetime(order['order_delivered_carrier_date'])
order['order_delivered_customer_date'] = pd.to_datetime(order['order_delivered_customer_date'])
order['order_estimated_delivery_date'] = pd.to_datetime(order['order_estimated_delivery_date'])
order['order_status'] = order['order_status'].astype('category')

# %%
order.loc[order['order_status'] == 'shipped']
# Out:
#                                 order_id                       customer_id  \
# 49      ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 161     6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 169     36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 241     4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 314     3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# ...                                  ...                               ...
# 103196  dab8a6c6bd6ec448df5b3a6b6cb887bc  394653a10cab83cad40d7e2713f3ab89
# 103354  492aed3c33bac22a8e04138319829283  58466c1166c377a56f6b2ae0d93ffbc0
# 103543  274a7f7e4f1c17b7434a830e9b8759b1  670af30ca5b8c20878fecdafa5ee01b9
# 103544  274a7f7e4f1c17b7434a830e9b8759b1  670af30ca5b8c20878fecdafa5ee01b9
# 103616  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
#
#        order_status order_purchase_timestamp   order_approved_at  \
# 49          shipped      2018-06-04 16:44:48 2018-06-05 04:31:18
# 161         shipped      2018-01-10 11:33:07 2018-01-11 02:32:30
# 169         shipped      2017-05-09 11:48:37 2017-05-11 11:45:14
# 241         shipped      2017-11-17 19:53:21 2017-11-18 19:50:31
# 314         shipped      2018-06-28 12:52:15 2018-06-28 13:11:09
# ...             ...                      ...                 ...
# 103196      shipped      2018-07-14 10:12:51 2018-07-16 12:30:58
# 103354      shipped      2018-07-06 16:26:47 2018-07-06 16:35:10
# 103543      shipped      2018-06-23 13:25:15 2018-06-23 13:40:11
# 103544      shipped      2018-06-23 13:25:15 2018-06-23 13:40:11
# 103616      shipped      2018-02-17 14:31:22 2018-02-20 07:11:31
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 49              2018-06-05 14:32:00                           NaT
# 161             2018-01-11 19:39:23                           NaT
# 169             2017-05-11 13:21:47                           NaT
# 241             2017-11-22 17:28:34                           NaT
# 314             2018-07-04 15:20:00                           NaT
# ...                             ...                           ...
# 103196          2018-07-16 14:34:00                           NaT
# 103354          2018-07-10 12:27:00                           NaT
# 103543          2018-07-04 13:51:00                           NaT
# 103544          2018-07-04 13:51:00                           NaT
# 103616          2018-02-20 19:18:58                           NaT
#
#        order_estimated_delivery_date payment_type  payment_value  \
# 49                        2018-06-28       boleto          22.36
# 161                       2018-02-07       boleto          69.12
# 169                       2017-06-08  credit_card          63.79
# 241                       2017-12-13  credit_card         240.23
# 314                       2018-08-03  credit_card         865.01
# ...                              ...          ...            ...
# 103196                    2018-08-03       boleto         121.90
# 103354                    2018-07-26  credit_card         280.42
# 103543                    2018-07-24  credit_card           9.31
# 103544                    2018-07-24      voucher          48.63
# 103616                    2018-03-14       boleto         224.71
#
#         customer_zip_code_prefix   customer_city customer_state  \
# 49                         13215         jundiai             SP
# 161                        38600        paracatu             MG
# 169                        54762      camaragibe             PE
# 241                        91450    porto alegre             RS
# 314                        20910  rio de janeiro             RJ
# ...                          ...             ...            ...
# 103196                     25942      guapimirim             RJ
# 103354                      8270       sao paulo             SP
# 103543                     49030         aracaju             SE
# 103544                     49030         aracaju             SE
# 103616                     12042         taubate             SP
#
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 49                          13215.0       -23.175897       -46.886594
# 161                         38600.0       -17.211338       -46.886436
# 169                         54762.0        -8.026146       -34.975079
# 241                         91450.0       -30.047581       -51.134612
# 314                         20910.0       -22.899783       -43.228535
# ...                             ...              ...              ...
# 103196                      25942.0       -22.595404       -43.012676
# 103354                       8270.0       -23.563363       -46.459684
# 103543                      49030.0       -10.970165       -37.061644
# 103544                      49030.0       -10.970165       -37.061644
# 103616                      12042.0       -23.034163       -45.616345
#
# [1166 rows x 16 columns]

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103887 entries, 0 to 103886
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       103887 non-null  object
#  1   customer_id                    103887 non-null  object
#  2   order_status                   103887 non-null  category
#  3   order_purchase_timestamp       103887 non-null  datetime64[ns]
#  4   order_approved_at              103712 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   101999 non-null  datetime64[ns]
#  6   order_delivered_customer_date  100755 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  103887 non-null  datetime64[ns]
#  8   payment_type                   103886 non-null  object
#  9   payment_value                  103886 non-null  float64
#  10  customer_zip_code_prefix       103887 non-null  int64
#  11  customer_city                  103887 non-null  object
#  12  customer_state                 103887 non-null  object
#  13  geolocation_zip_code_prefix    103600 non-null  float64
#  14  geolocation_lat                103600 non-null  float64
#  15  geolocation_lng                103600 non-null  float64
# dtypes: category(1), datetime64[ns](5), float64(4), int64(1), object(5)
# memory usage: 12.8+ MB

# %%
order = order.dropna(subset = ["payment_type","payment_value"])

# %%
order.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# order_estimated_delivery_date       0
# payment_type                        0
# payment_value                       0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# geolocation_zip_code_prefix       287
# geolocation_lat                   287
# geolocation_lng                   287
# dtype: int64

# %%
order = order.drop_duplicates()

# %%
print("Jumlah duplikasi: ",order.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ## EDA

# %%
df_order.describe(include="all")
# Out:
# <ipython-input-52-f0017f01a484>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_order.describe(include="all")
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# first                                NaN            NaN
# last                                 NaN            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
# freq                                 527                              2033
# first                                NaN                               NaN
# last                                 NaN                               NaN
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         shipping_limit_date          price  freight_value  \
# count                112650  112650.000000  112650.000000
# unique                93318            NaN            NaN
# top     2017-07-21 18:25:23            NaN            NaN
# freq                     21            NaN            NaN
# first   2016-09-19 00:15:34            NaN            NaN
# last    2020-04-09 22:35:08            NaN            NaN
# mean                    NaN     120.653739      19.990320
# std                     NaN     183.633928      15.806405
# min                     NaN       0.850000       0.000000
# 25%                     NaN      39.900000      13.080000
# 50%                     NaN      74.990000      16.260000
# 75%                     NaN     134.900000      21.150000
# max                     NaN    6735.000000     409.680000
#
#        product_category_name product_category_name_english  \
# count                 112650                        112650
# unique                    74                            74
# top          cama_mesa_banho                bed_bath_table
# freq                   11115                         11115
# first                    NaN                           NaN
# last                     NaN                           NaN
# mean                     NaN                           NaN
# std                      NaN                           NaN
# min                      NaN                           NaN
# 25%                      NaN                           NaN
# 50%                      NaN                           NaN
# 75%                      NaN                           NaN
# max                      NaN                           NaN
#
#         seller_zip_code_prefix seller_city seller_state  \
# count            112650.000000      112650       112650
# unique                     NaN         611           23
# top                        NaN   sao paulo           SP
# freq                       NaN       27983        80342
# first                      NaN         NaN          NaN
# last                       NaN         NaN          NaN
# mean              24439.170431         NaN          NaN
# std               27596.030909         NaN          NaN
# min                1001.000000         NaN          NaN
# 25%                6429.000000         NaN          NaN
# 50%               13568.000000         NaN          NaN
# 75%               27930.000000         NaN          NaN
# max               99730.000000         NaN          NaN
#
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 112397.000000    112397.000000    112397.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# first                           NaN              NaN              NaN
# last                            NaN              NaN              NaN
# mean                   24435.840191       -22.800558       -47.235919
# std                    27593.085486         2.697063         2.341211
# min                     1001.000000       -36.605374       -67.809656
# 25%                     6429.000000       -23.610305       -48.831547
# 50%                    13568.000000       -23.422313       -46.747050
# 75%                    27345.000000       -21.766477       -46.518082
# max                    99730.000000        -2.546079       -34.847856

# %% [markdown]
# Dari tabel diatas bisa terlihat bahwa nama kategori yang paling banyak dibeli adalah bed_bath_table	dan kota seller yang paling menjual adalah sao paulo

# %%
# mendefinisikan fungsi yang akan digunakan untuk EDA
def range(series):
    return series.max() - series.min()

# %%
df_order.groupby(by="product_category_name_english").agg({
    "product_id": "count", #jumlah pembelian
    "price": ["max", "min", "mean", range]
}).sort_values(by=("product_id", "count"), ascending=False)
# Out:
#                               product_id    price
#                                    count      max     min        mean    range
# product_category_name_english
# bed_bath_table                     11115  1999.98    6.99   93.296327  1992.99
# health_beauty                       9670  3124.00    1.20  130.163531  3122.80
# sports_leisure                      8641  4059.00    4.50  114.344285  4054.50
# furniture_decor                     8334  1899.00    4.90   87.564494  1894.10
# computers_accessories               7827  3699.99    3.90  116.513903  3696.09
# ...                                  ...      ...     ...         ...      ...
# cds_dvds_musicals                     14    65.00   45.00   52.142857    20.00
# la_cuisine                            14   389.00   24.00  146.785000   365.00
# PC Gaming                              9   239.00  129.99  171.772222   109.01
# fashion_childrens_clothes              8   110.00   39.99   71.231250    70.01
# security_and_services                  2   183.29  100.00  141.645000    83.29
#
# [74 rows x 5 columns]

# %% [markdown]
# bed_bath_table adalah produk yang banyak dibeli dan health_beauty adalah produk yang menghasilkan rata rata harga tertinggi

# %%
df_order.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# SP merupakan state dengan penjual terbanyak

# %%
df_order.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %% [markdown]
# Sao paulo merupakan kota dengan seller terbanyak

# %%
order.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Sao paulo merupakan kota dengan customer terbanyak

# %%
order.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41745
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# SP merupakan state dengan customer terbanyak

# %% [markdown]
# ## Visualization & Explanatory analysis

# %%
category = df_order.groupby(by="product_category_name_english")["product_id"].count().reset_index() #jumlah pembelian
category = category.rename(columns={"product_category_name_english": "name", "product_id": "sum"})

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="sum", y="name", data=category.sort_values(by="sum", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="sum", y="name", data=category.sort_values(by="sum", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# Terlihat bahwa kategori barang yang paling banyak dibeli adalah bed_bath_table sedangkan   paling sedikit dibeli adalah security_and_services

# %%
order['year'] = order['order_purchase_timestamp'].dt.strftime('%Y')
order['month'] = order['order_purchase_timestamp'].dt.strftime('%m-%Y')
# df_order_items

order["lama_pengiriman_hari"] = (order["order_delivered_customer_date"] - order["order_delivered_carrier_date"]).dt.days
order["hari_pembelian"] = order["order_purchase_timestamp"].dt.strftime('%A')

order['jam_pembelian'] = order['order_purchase_timestamp'].apply(lambda x: x.hour)
hours_bins = [-0.1, 6, 12, 18, 23]
hours_labels = ['Subuh', 'Pagi', 'Siang', 'Malam']
order['waktu_hari_pembelian'] = pd.cut(order['jam_pembelian'], hours_bins, labels=hours_labels)

# %%
order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date payment_type  payment_value  ...  \
# 0                    2017-10-18  credit_card          18.12  ...
# 1                    2017-10-18      voucher           2.00  ...
# 2                    2017-10-18      voucher          18.59  ...
# 3                    2018-08-13       boleto         141.46  ...
# 4                    2018-09-04  credit_card         179.12  ...
#
#    customer_state geolocation_zip_code_prefix geolocation_lat  \
# 0              SP                      3149.0      -23.574809
# 1              SP                      3149.0      -23.574809
# 2              SP                      3149.0      -23.574809
# 3              BA                     47813.0      -12.169860
# 4              GO                     75265.0      -16.746337
#
#    geolocation_lng  year    month lama_pengiriman_hari hari_pembelian  \
# 0       -46.587471  2017  10-2017                  6.0         Monday
# 1       -46.587471  2017  10-2017                  6.0         Monday
# 2       -46.587471  2017  10-2017                  6.0         Monday
# 3       -44.988369  2018  07-2018                 12.0        Tuesday
# 4       -48.514624  2018  08-2018                  9.0      Wednesday
#
#    jam_pembelian waktu_hari_pembelian
# 0             10                 Pagi
# 1             10                 Pagi
# 2             10                 Pagi
# 3             20                Malam
# 4              8                 Pagi
#
# [5 rows x 22 columns]

# %%
tanggal =  order.groupby(by=["month","year"]).order_id.nunique().reset_index()
tanggal["month"] = pd.to_datetime(tanggal["month"], format='%m-%Y')

# %%
df_order_2017 = order[order['year'] == '2017']
x = df_order_2017.groupby('month')['order_id'].nunique()
x_diff  = x.diff().fillna(0)
print(x_diff)

# dalam persentase
print("----\npersentase kenaikan penjualan : ")
x_percentage = x.pct_change().fillna(0) * 100
x_percentage
# Out:
# month
# 01-2017       0.0
# 02-2017     980.0
# 03-2017     902.0
# 04-2017    -278.0
# 05-2017    1296.0
# 06-2017    -455.0
# 07-2017     781.0
# 08-2017     305.0
# 09-2017     -46.0
# 10-2017     346.0
# 11-2017    2913.0
# 12-2017   -1871.0
# Name: order_id, dtype: float64
# ----
# persentase kenaikan penjualan :
# month
# 01-2017      0.000000
# 02-2017    122.500000
# 03-2017     50.674157
# 04-2017    -10.365399
# 05-2017     53.910150
# 06-2017    -12.297297
# 07-2017     24.067797
# 08-2017      7.575758
# 09-2017     -1.062110
# 10-2017      8.074679
# 11-2017     62.902181
# 12-2017    -24.801166
# Name: order_id, dtype: float64

# %%
plt.figure(figsize=(20, 6))

ax = sns.lineplot(x='month', y='order_id', data=tanggal, estimator=None,linewidth=3)
ax.set(xticks=tanggal.month.values)

plt.title("Tren Pertumbuhan Penjualan", loc="center", fontsize=18)
plt.ylabel("total order")
plt.xlabel(None)
ax.grid(False)
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

# %% [markdown]
# pembelian terbanyak terjadi pada bulan novembertahun 2017

# %%
df_bagian_hari = order.groupby(by="waktu_hari_pembelian")["order_id"].nunique().reset_index()
df_bagian_hari.rename(columns={
    "order_id": "total_orders"
}, inplace=True)

# %%
plt.figure(figsize=(10, 5))

colors = ["#D3D3D3", "#D3D3D3", "#102cd4", "#D3D3D3"]

sns.barplot(
    x="waktu_hari_pembelian",
    y="total_orders",
    data=df_bagian_hari.sort_values(by="total_orders"),
    palette=colors
)
plt.title("persebaran pembelian berdasarkan bagian hari", loc="center", fontsize=15)
plt.ylabel("total order")
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %%
df_hari = order.groupby(by="hari_pembelian").order_id.nunique().sort_values(ascending=False).reset_index()
df_hari.rename(columns={
    "order_id": "total_orders"
}, inplace=True)
df_hari
# Out:
#   hari_pembelian  total_orders
# 0         Monday         16196
# 1        Tuesday         15963
# 2      Wednesday         15552
# 3       Thursday         14760
# 4         Friday         14122
# 5         Sunday         11960
# 6       Saturday         10887

# %%
plt.figure(figsize=(10, 5))

colors = ["#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3", "#102cd4"]

sns.barplot(
    x="hari_pembelian",
    y="total_orders",
    data=df_hari.sort_values(by="total_orders"),
    palette=colors
)
plt.title("persebaran pembelian berdasarkan hari", loc="center", fontsize=15)
plt.ylabel("total order")
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# Hari senin adalah hari yang paling banyak digunakan oleh konsumen untuk belanja dan umumnya konsumen melakukan transaksi pada siang hari.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. **Apa kategori barang yang paling banyak dibeli dan paling sedikit diminati?**
#
# > Kategori barang yang paling banyak dibeli adalah bed_bath_table sedangkan paling sedikit dibeli adalah security_and_services
#
#
# 2. **Bulan apa yang terjadi  penjualan tertinggi?**
#
#
# > Pembelian terbanyak terjadi pada bulan November tahun 2017
#
#
# 3.**Hari apa yang sering digunakan oleh pembeli untuk melakukan transaksi?**
#
#
# > Hari Senin adalah hari yang paling banyak digunakan oleh konsumen untuk belanja dan umumnya konsumen melakukan transaksi pada siang hari.
